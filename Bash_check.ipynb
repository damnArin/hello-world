# %% [markdown]
# <a href="https://colab.research.google.com/github/damnArin/hello-world/blob/master/Bash_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ref:
# 1. https://stackoverflow.com/questions/34805372/how-can-i-test-my-bash-script-on-older-versions-of-bash
# 2. https://stackoverflow.com/questions/48298146/changing-directory-in-google-colab-breaking-out-of-the-python-interpreter

# %%
# !echo $BASH_VERSION
# Out:
# 4.4.20(1)-release

# %%
# !mkdir bash
# %cd bash
# !pwd
# Out:
# mkdir: cannot create directory ‘bash’: File exists
# /content/bash
# /content/bash

# %%
# !wget http://ftp.gnu.org/gnu/bash/bash-3.2.57.tar.gz
# !tar xvzf bash-3.2.57.tar.gz
# !pwd
# Out:
# --2020-08-28 06:30:55--  http://ftp.gnu.org/gnu/bash/bash-3.2.57.tar.gz
# Resolving ftp.gnu.org (ftp.gnu.org)... 209.51.188.20, 2001:470:142:3::b
# Connecting to ftp.gnu.org (ftp.gnu.org)|209.51.188.20|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2542620 (2.4M) [application/x-gzip]
# Saving to: ‘bash-3.2.57.tar.gz.1’
#
# bash-3.2.57.tar.gz. 100%[===================>]   2.42M  3.86MB/s    in 0.6s
#
# 2020-08-28 06:30:56 (3.86 MB/s) - ‘bash-3.2.57.tar.gz.1’ saved [2542620/2542620]
#
# bash-3.2.57/
# bash-3.2.57/CWRU/
# bash-3.2.57/builtins/
# bash-3.2.57/cross-build/
# bash-3.2.57/doc/
# bash-3.2.57/examples/
# bash-3.2.57/include/
# bash-3.2.57/lib/
# bash-3.2.57/po/
# bash-3.2.57/support/
# bash-3.2.57/tests/
# bash-3.2.57/ABOUT-NLS
# bash-3.2.57/CHANGES
# bash-3.2.57/COMPAT
# bash-3.2.57/COPYING
# bash-3.2.57/INSTALL
# bash-3.2.57/MANIFEST
# bash-3.2.57/NEWS
# bash-3.2.57/NOTES
# bash-3.2.57/POSIX
# bash-3.2.57/README
# bash-3.2.57/RBASH
# ...

# %%
# %cd bash-3.2.57
# !./configure
# !ls -l
# !make
# Out:
# /content/bash/bash-3.2.57
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for emacs... no
# checking for xemacs... no
#
# Beginning configuration for bash-3.2-release for x86_64-unknown-linux-gnu
#
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ANSI C... none needed
# checking for strerror in -lcposix... no
# checking how to run the C preprocessor... gcc -E
# checking for egrep... grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# ...

# %%
# !./bash -version
# !echo hey
# !./bash script.sh
# Out:
# GNU bash, version 3.2.57(1)-release (x86_64-unknown-linux-gnu)
# Copyright (C) 2007 Free Software Foundation, Inc.
# hey
# hey
# hey
# cat: abc.txt: input file is output file

# %% [markdown]
# # if `make` fails due to yacc, run `sudo apt-get install byacc`
# # No need to run `make install`

# %%
# !apt-get install byacc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   byacc
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 61.3 kB of archives.
# After this operation, 167 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 byacc amd64 20140715-1build1 [61.3 kB]
# Fetched 61.3 kB in 0s (915 kB/s)
# Selecting previously unselected package byacc.
# (Reading database ... 144556 files and directories currently installed.)
# Preparing to unpack .../byacc_20140715-1build1_amd64.deb ...
# Unpacking byacc (20140715-1build1) ...
# Setting up byacc (20140715-1build1) ...
# update-alternatives: using /usr/bin/byacc to provide /usr/bin/yacc (yacc) in auto mode
# ...

# %%
# !pwd
# !ls -l
# !cd bash-3.2.57
# !pwd
# Out:
# /content
# total 2496
# drwxr-xr-x  2 root root     4096 Aug 28 06:19 bash
# drwxrwxr-x 12  286 staff    4096 Oct  5  2014 bash-3.2.57
# -rw-r--r--  1 root root  2542620 Nov  7  2014 bash-3.2.57.tar.gz
# drwxr-xr-x  1 root root     4096 Aug 24 16:35 sample_data
# /content

# %%
# !bash -version
# Out:
# GNU bash, version 4.4.20(1)-release (x86_64-pc-linux-gnu)
# Copyright (C) 2016 Free Software Foundation, Inc.
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>
#
# This is free software; you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
